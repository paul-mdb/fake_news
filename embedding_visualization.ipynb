# %%
import pandas as pd
import numpy as np

from transformers import logging
logging.set_verbosity_error()
import torch
pd.options.display.max_colwidth = 1000
pd.set_option('display.expand_frame_repr', False)

from transformers import CamembertForSequenceClassification, CamembertTokenizer

# %%
model = CamembertForSequenceClassification.from_pretrained(
        'camembert-base',
        num_labels = 3)
PATH = 'first_camembert_model.model'
model.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# CamembertForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(32005, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=3, bias=True)
#   )
# )

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter('runs/testing_tensorboard_pt')

# %%
import tensorflow as tf
import tensorboard as tb
tf.io.gfile = tb.compat.tensorflow_stub.io.gfile

# %%
TOKENIZER = CamembertTokenizer.from_pretrained(
    'camembert-base',
    do_lower_case=True)

words = list(TOKENIZER.get_vocab().keys())
words += ["caca"]

# %%
word_embedding = model.roberta.embeddings.word_embeddings.weight
writer.add_embedding(word_embedding,
                         metadata  = words,
                        tag = f'word embedding')

# %%
position_embedding = model.roberta.embeddings.position_embeddings.weight
writer.add_embedding(position_embedding,
                     metadata  = np.arange(position_embedding.shape[0]),
                     tag = f'position embedding')

# %%
"""token_type_embedding = model.roberta.embeddings.token_type_embeddings.weight
writer.add_embedding(token_type,
                     metadata  = np.arange(token_type_embedding.shape[0]),
                     tag = f'tokentype embeddings')"""
# Out:
# "token_type_embedding = model.roberta.embeddings.token_type_embeddings.weight\nwriter.add_embedding(token_type,\n                     metadata  = np.arange(token_type_embedding.shape[0]),\n                     tag = f'tokentype embeddings')"

# %%
writer.close()

# %%
# !tensorboard --logdir=C:/Users/louis/Desktop/NLP/fake_news/runs/testing_tensorboard_pt
# Out:
# 2022-02-03 15:53:49.068073: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-02-03 15:53:49.068720: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-02-03 15:53:56.415176: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-02-03 15:53:56.416195: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-02-03 15:53:56.424736: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G88VB4B
# 2022-02-03 15:53:56.425557: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G88VB4B
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.7.0 at http://localhost:6006/ (Press CTRL+C to quit)
# Windows fatal exception: access violation
#
# Current thread 0x00003628 (most recent call first):
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\event_file_loader.py", line 138 in Load
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\event_file_loader.py", line 163 in Load
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\event_file_loader.py", line 189 in Load
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\directory_watcher.py", line 118 in _LoadInternal
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\directory_watcher.py", line 88 in Load
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\plugin_event_accumulator.py", line 177 in Reload
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\plugin_event_multiplexer.py", line 233 in Worker
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\plugin_event_multiplexer.py", line 255 in Reload
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\data_ingester.py", line 102 in _reload
#   File "c:\users\louis\miniconda3\lib\threading.py", line 892 in run
#   File "c:\users\louis\miniconda3\lib\threading.py", line 954 in _bootstrap_inner
#   File "c:\users\louis\miniconda3\lib\threading.py", line 912 in _bootstrap
#
# Thread 0x00003520 (most recent call first):
#   File "c:\users\louis\miniconda3\lib\selectors.py", line 315 in _select
#   File "c:\users\louis\miniconda3\lib\selectors.py", line 324 in select
#   File "c:\users\louis\miniconda3\lib\socketserver.py", line 232 in serve_forever
#   File "c:\users\louis\miniconda3\lib\site-packages\werkzeug\serving.py", line 719 in serve_forever
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\program.py", line 295 in _run_serve_subcommand
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\program.py", line 276 in main
#   File "c:\users\louis\miniconda3\lib\site-packages\absl\app.py", line 251 in _run_main
#   File "c:\users\louis\miniconda3\lib\site-packages\absl\app.py", line 303 in run
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\main.py", line 46 in run_main
#   File "C:\Users\louis\miniconda3\Scripts\tensorboard.exe\__main__.py", line 7 in <module>
#   File "c:\users\louis\miniconda3\lib\runpy.py", line 87 in _run_code
#   File "c:\users\louis\miniconda3\lib\runpy.py", line 197 in _run_module_as_main
# 2022-02-03 15:48:56.645134: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-02-03 15:48:56.645701: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-02-03 15:49:01.735403: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-02-03 15:49:01.736453: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-02-03 15:49:01.744929: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G88VB4B
# 2022-02-03 15:49:01.745775: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G88VB4B
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.7.0 at http://localhost:6006/ (Press CTRL+C to quit)
# Windows fatal exception: access violation
#
# Current thread 0x00002eac (most recent call first):
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\event_file_loader.py", line 138 in Load
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\event_file_loader.py", line 163 in Load
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\event_file_loader.py", line 189 in Load
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\directory_watcher.py", line 118 in _LoadInternal
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\directory_watcher.py", line 88 in Load
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\plugin_event_accumulator.py", line 177 in Reload
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\plugin_event_multiplexer.py", line 233 in Worker
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\plugin_event_multiplexer.py", line 255 in Reload
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\backend\event_processing\data_ingester.py", line 102 in _reload
#   File "c:\users\louis\miniconda3\lib\threading.py", line 892 in run
#   File "c:\users\louis\miniconda3\lib\threading.py", line 954 in _bootstrap_inner
#   File "c:\users\louis\miniconda3\lib\threading.py", line 912 in _bootstrap
#
# Thread 0x00004888 (most recent call first):
#   File "c:\users\louis\miniconda3\lib\selectors.py", line 315 in _select
#   File "c:\users\louis\miniconda3\lib\selectors.py", line 324 in select
#   File "c:\users\louis\miniconda3\lib\socketserver.py", line 232 in serve_forever
#   File "c:\users\louis\miniconda3\lib\site-packages\werkzeug\serving.py", line 719 in serve_forever
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\program.py", line 295 in _run_serve_subcommand
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\program.py", line 276 in main
#   File "c:\users\louis\miniconda3\lib\site-packages\absl\app.py", line 251 in _run_main
#   File "c:\users\louis\miniconda3\lib\site-packages\absl\app.py", line 303 in run
#   File "c:\users\louis\miniconda3\lib\site-packages\tensorboard\main.py", line 46 in run_main
#   File "C:\Users\louis\miniconda3\Scripts\tensorboard.exe\__main__.py", line 7 in <module>
#   File "c:\users\louis\miniconda3\lib\runpy.py", line 87 in _run_code
#   File "c:\users\louis\miniconda3\lib\runpy.py", line 197 in _run_module_as_main
